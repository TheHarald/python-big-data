# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import ensemble
from sklearn.model_selection import GridSearchCV
import time as time
from sklearn import preprocessing
warnings.filterwarnings('ignore')
from sklearn.metrics import f1_score

# %%
#1
data = pd.read_csv('riceClassification.csv', sep=',')
data = data.sample(1000)
DATA = data.drop(['id', 'Class'], axis=1)
scaler = preprocessing.MinMaxScaler()
D = pd.DataFrame(scaler.fit_transform(DATA), columns = DATA.columns)
D
# Out:
#          Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    0.355389         0.635736         0.290953      0.894787    0.352949
# 1    0.384993         0.863739         0.162535      0.991655    0.378016
# 2    0.561528         0.848367         0.427826      0.906647    0.558981
# 3    0.402046         0.681031         0.314051      0.900016    0.399464
# 4    0.293997         0.627232         0.184776      0.933934    0.286863
# ..        ...              ...              ...           ...         ...
# 995  0.495089         0.817038         0.350113      0.925164    0.492359
# 996  0.558663         0.837041         0.428790      0.903180    0.559786
# 997  0.669168         0.756056         0.635491      0.789670    0.658579
# 998  0.505321         0.870745         0.338334      0.941890    0.506166
# 999  0.831651         0.841555         0.790380      0.756264    0.838874
#
#      EquivDiameter    Extent  Perimeter  Roundness  AspectRation
# 0         0.430469  0.545764   0.381339   0.705055      0.604725
# 1         0.461090  0.334135   0.492287   0.580807      0.952696
# 2         0.632696  0.121903   0.554206   0.678993      0.634633
# 3         0.478465  0.306979   0.421796   0.699052      0.617623
# 4         0.364975  0.541114   0.351239   0.672716      0.713587
# ..             ...       ...        ...        ...           ...
# 995       0.570143  0.266174   0.501814   0.684742      0.686483
# 996       0.630045  0.475808   0.563700   0.663436      0.625645
# 997       0.729587  0.361539   0.515844   0.844555      0.413012
# 998       0.579925  0.683790   0.540820   0.641671      0.739817
# 999       0.866971  0.449632   0.616406   0.840344      0.370042
#
# [1000 rows x 10 columns]

# %%
# 2
bagging_data = D.copy()
target = data['Class']

X_train, X_test, y_train, y_test = train_test_split(bagging_data, target, test_size=0.3, random_state=42)


params_grid = {
    'max_depth': [12,18],
    'min_samples_split': [6, 12],
    'min_samples_leaf': [3,10],
}

grid_search_random_forest = GridSearchCV(ensemble.RandomForestClassifier(), 
    params_grid, 
    cv=4,
    scoring='f1_macro', 
)

start = time.time()
grid_search_random_forest.fit(X_train, y_train)
bagging_time = time.time() - start
best_model = grid_search_random_forest.best_estimator_
random_forest_predictions = best_model.predict(X_test)
random_forest_test = best_model.predict(X_train)
print('Время работы Баггинга: ', bagging_time)
print('F1 для тренировочных данных: ', f1_score(y_train, random_forest_test, average='macro'))
print('F1 для тестовых данных: ', f1_score(y_test, random_forest_predictions, average='macro'))
# Out:
# Время работы Баггинга:  3.521416187286377
# F1 для тренировочных данных:  0.9956895755463463
# F1 для тестовых данных:  0.9799277398635087

# %%
# 3

model_boosting = ensemble.GradientBoostingClassifier()
start = time.time()
model_boosting.fit(X_train, y_train)
boosting_time = time.time() - start

boosting_train = model_boosting.predict(X_train)
boosting_test = model_boosting.predict(X_test)
print('Время работы Бустинга: ', boosting_time)
print('F1 для тренировочных данных: ', f1_score(y_train, boosting_train, average='macro'))
print('F1 для тестовых данных: ', f1_score(y_test, boosting_test, average='macro'))
# Out:
# Время работы Бустинга:  0.15399909019470215
# F1 для тренировочных данных:  1.0
# F1 для тестовых данных:  0.9765914993701998
